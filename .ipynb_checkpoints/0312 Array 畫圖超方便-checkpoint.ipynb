# %% [markdown]
# x = np.linspace(0,10,100) --> 從 0 到 10 描 100 個點
#
# plt.plot(x,np.sin(x))
#
# 重複指令兩次，可以把圖形放在一起

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.rand(50)

# %%
y
# Out:
# array([ 0.67886042,  0.51387063,  0.5495189 ,  0.40763547,  0.05063062,
#         0.40121611,  0.17238957,  0.97175695,  0.80316735,  0.05519144,
#         0.60169672,  0.07551571,  0.75746144,  0.92745506,  0.7595705 ,
#         0.52280399,  0.57018953,  0.67556253,  0.3316621 ,  0.94535849,
#         0.80446769,  0.91393603,  0.1107372 ,  0.33632905,  0.9625733 ,
#         0.11112911,  0.12125904,  0.58578163,  0.24248472,  0.71806133,
#         0.01172193,  0.18355097,  0.07397504,  0.6679594 ,  0.08390477,
#         0.52774478,  0.04384537,  0.70239086,  0.8548365 ,  0.81611318,
#         0.43069629,  0.35057945,  0.21574676,  0.79451369,  0.6486618 ,
#         0.42447541,  0.12017672,  0.9459041 ,  0.25237616,  0.11992278])

# %%
plt.plot(y)

# %%
x = np.linspace(0, 10, 100)

# %%
x
# Out:
# array([  0.        ,   0.1010101 ,   0.2020202 ,   0.3030303 ,
#          0.4040404 ,   0.50505051,   0.60606061,   0.70707071,
#          0.80808081,   0.90909091,   1.01010101,   1.11111111,
#          1.21212121,   1.31313131,   1.41414141,   1.51515152,
#          1.61616162,   1.71717172,   1.81818182,   1.91919192,
#          2.02020202,   2.12121212,   2.22222222,   2.32323232,
#          2.42424242,   2.52525253,   2.62626263,   2.72727273,
#          2.82828283,   2.92929293,   3.03030303,   3.13131313,
#          3.23232323,   3.33333333,   3.43434343,   3.53535354,
#          3.63636364,   3.73737374,   3.83838384,   3.93939394,
#          4.04040404,   4.14141414,   4.24242424,   4.34343434,
#          4.44444444,   4.54545455,   4.64646465,   4.74747475,
#          4.84848485,   4.94949495,   5.05050505,   5.15151515,
#          5.25252525,   5.35353535,   5.45454545,   5.55555556,
#          5.65656566,   5.75757576,   5.85858586,   5.95959596,
# ...

# %%
plt.plot(x, np.sin(x)+x)

# %%
plt.plot(x, np.sin(x) +x)
plt.plot(x, np.cos(x))
