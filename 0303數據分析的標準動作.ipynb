# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([3,-4,1,5,-2,6])

# %%
plt.plot(np.random.randn(100))

# %% [markdown]
# %matplotlib inline  #畫圖用的套件
#
# import numpy as np #運算函數
#
# import matplotlib.pyplot as plt #畫圖用pyplot
#
# plt.plot(np.random.randn(100))
#
# TAB鍵
