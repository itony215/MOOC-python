# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2,10,3,13,5])

# %%
randn(10)
# Out:
# array([-0.54490124, -0.77942478,  1.83804187, -1.36471364,  0.74049196,
#         0.97583348, -0.26350099, -0.1420784 ,  0.3931487 , -0.41264073])

# %%
plot(randn(10))

# %%
plot([2,4,1,3],[2,3,1,4])
